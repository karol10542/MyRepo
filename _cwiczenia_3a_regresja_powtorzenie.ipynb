# %% [markdown]
# <a href="https://colab.research.google.com/github/karol10542/MyRepo/blob/main/_cwiczenia_3a_regresja_powtorzenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A regression example**
#
# Common type of machine learning problem is "regression", which consists of predicting a continuous value instead of a discrete label. For instance, predicting the temperature tomorrow, given meteorological data, or predicting the time that a software project will take to complete, given its specifications.

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras import optimizers

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1-dimensional data**

# %%
def funct(x):
  return x*x*np.sin(x)+np.log(2*x)

size = 200
low=0
high=12
error=20

XX_train = np.random.uniform(low=low, high=high, size=size)
XX_test = np.random.uniform(low=low, high=high, size=size)
yy_train = funct(XX_train) + np.random.normal(0., error, size)
yy_test = funct(XX_test) + np.random.normal(0., error, size)

print(XX_train.shape, yy_train.shape)
# Out:
# (200,) (200,)

# %% [markdown]
# Plot the function and data

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(XX_train,yy_train, 'o', color='blue', label='Training points')
plt.plot(XX_test,yy_test, 'o', color='green', label='Testing points')

points = np.linspace(low, high,num=100)
plt.plot(points, funct(points),  color='red', label='Function')
plt.legend()


plt.show
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Preparing the data**
#
# It would be problematic to feed into a neural network values that all take wildly different ranges. The network might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice to deal with such data is to do feature-wise normalization: for each feature in the input data (a column in the input data matrix), we will subtract the mean of the feature and divide by the standard deviation, so that the feature will be centered around 0 and will have a unit standard deviation. This is easily done in Numpy:

# %%
# Tutaj należy znormalizować dane, i.e. 
# - odjąć średnią
# - podzielić przez odchylenie standardowe

# 
mean = XX_train.mean(axis=0)
XX_train_n = XX_train-mean
std = XX_train_n.std(axis=0)
XX_train_n /= std

# to samo dla X_test
XX_test_n = XX_test - mean
XX_test_n /= std

# A teraz to samo dla yy_train i yy_test
mean1=yy_train.mean(axis=0)
yy_train_n=yy_train-mean1
std1=yy_train_n.std(axis=0)
yy_train_n /=std1

yy_test_n= yy_test-mean1
yy_test_n /= std1

# %% [markdown]
# Define neural network

# %%
# Zbudować sieć neuronową, działa: dwie warstwy ukryte, aktywacja relu
from keras import models
from keras import layers

model0 = Sequential(name='network')
#.....
model0.add(layers.Dense(1024,activation='relu',input_shape=(1,)))
model0.add(Dropout(0.1))
model0.add(layers.Dense(1024,activation='relu'))
model0.add(Dropout(0.1))
model0.add(layers.Dense(1,activation='linear'))

model0.summary()
# Out:
# Model: "network"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1024)              2048
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 1,052,673
# Trainable params: 1,052,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train neural network
#
# For regression problems, mean squared error (MSE) is often employed

# %%
# compile and train NN
# Uwaga: dla regresji używamy: loss = 'mean_squared_error'   oraz metrics = ['mse']

opt=optimizers.RMSprop(lr=0.001)
model0.compile(optimizer=opt,
                       loss='mean_squared_error',
                       metrics=['mse'])
history = model0.fit(XX_train_n, yy_train_n,
                                     epochs=500,
                                     batch_size=128,
                                     validation_data=(XX_test_n, yy_test_n),
                                     verbose = 1)
# Out:
# Epoch 1/500
# WARNING:tensorflow:6 out of the last 19 calls to <function Model.make_train_function.<locals>.train_function at 0x7fdfa3f98bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 197ms/step - loss: 1.0121 - mse: 1.0121 - val_loss: 0.8260 - val_mse: 0.8260
# Epoch 2/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8746 - mse: 0.8746 - val_loss: 0.6949 - val_mse: 0.6949
# Epoch 3/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7579 - mse: 0.7579 - val_loss: 0.8202 - val_mse: 0.8202
# Epoch 4/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7546 - mse: 0.7546 - val_loss: 0.5843 - val_mse: 0.5843
# Epoch 5/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6477 - mse: 0.6477 - val_loss: 0.5564 - val_mse: 0.5564
# Epoch 6/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5580 - mse: 0.5580 - val_loss: 0.5478 - val_mse: 0.5478
# Epoch 7/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6867 - mse: 0.6867 - val_loss: 0.4895 - val_mse: 0.4895
# Epoch 8/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5074 - mse: 0.5074 - val_loss: 0.4106 - val_mse: 0.4106
# Epoch 9/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4388 - mse: 0.4388 - val_loss: 0.3831 - val_mse: 0.3831
# Epoch 10/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3972 - mse: 0.3972 - val_loss: 0.5769 - val_mse: 0.5769
# Epoch 11/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5267 - mse: 0.5267 - val_loss: 0.3343 - val_mse: 0.3343
# Epoch 12/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3624 - mse: 0.3624 - val_loss: 0.3375 - val_mse: 0.3375
# Epoch 13/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3648 - mse: 0.3648 - val_loss: 0.2903 - val_mse: 0.2903
# Epoch 14/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2969 - mse: 0.2969 - val_loss: 0.2778 - val_mse: 0.2778
# Epoch 15/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3341 - mse: 0.3341 - val_loss: 0.4184 - val_mse: 0.4184
# Epoch 16/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4868 - mse: 0.4868 - val_loss: 0.3253 - val_mse: 0.3253
# Epoch 17/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3583 - mse: 0.3583 - val_loss: 0.2523 - val_mse: 0.2523
# Epoch 18/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2756 - mse: 0.2756 - val_loss: 0.2457 - val_mse: 0.2457
# Epoch 19/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2607 - val_mse: 0.2607
# Epoch 20/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2496 - mse: 0.2496 - val_loss: 0.3095 - val_mse: 0.3095
# Epoch 21/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3164 - mse: 0.3164 - val_loss: 0.2949 - val_mse: 0.2949
# Epoch 22/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2745 - mse: 0.2745 - val_loss: 0.2780 - val_mse: 0.2780
# Epoch 23/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2745 - mse: 0.2745 - val_loss: 0.2564 - val_mse: 0.2564
# Epoch 24/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 0.2816 - val_mse: 0.2816
# Epoch 25/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2455 - mse: 0.2455 - val_loss: 0.2724 - val_mse: 0.2724
# Epoch 26/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2651 - mse: 0.2651 - val_loss: 0.3824 - val_mse: 0.3824
# Epoch 27/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3767 - mse: 0.3767 - val_loss: 0.3950 - val_mse: 0.3950
# Epoch 28/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3723 - mse: 0.3723 - val_loss: 0.2654 - val_mse: 0.2654
# Epoch 29/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 0.2649 - val_mse: 0.2649
# Epoch 30/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2251 - mse: 0.2251 - val_loss: 0.2291 - val_mse: 0.2291
# Epoch 31/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2134 - mse: 0.2134 - val_loss: 0.2322 - val_mse: 0.2322
# Epoch 32/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2069 - mse: 0.2069 - val_loss: 0.2643 - val_mse: 0.2643
# Epoch 33/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2743 - mse: 0.2743 - val_loss: 0.2366 - val_mse: 0.2366
# Epoch 34/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2181 - val_mse: 0.2181
# Epoch 35/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1934 - mse: 0.1934 - val_loss: 0.2240 - val_mse: 0.2240
# Epoch 36/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2021 - mse: 0.2021 - val_loss: 0.2287 - val_mse: 0.2287
# Epoch 37/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2118 - mse: 0.2118 - val_loss: 0.2473 - val_mse: 0.2473
# Epoch 38/500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2408 - mse: 0.2408 - val_loss: 0.2465 - val_mse: 0.2465
# Epoch 39/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.2370 - mse: 0.2370 - val_loss: 0.2253 - val_mse: 0.2253
# Epoch 40/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2268 - mse: 0.2268 - val_loss: 0.3477 - val_mse: 0.3477
# Epoch 41/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3239 - mse: 0.3239 - val_loss: 0.3437 - val_mse: 0.3437
# Epoch 42/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3616 - mse: 0.3616 - val_loss: 0.2956 - val_mse: 0.2956
# Epoch 43/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2682 - mse: 0.2682 - val_loss: 0.2469 - val_mse: 0.2469
# Epoch 44/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2139 - mse: 0.2139 - val_loss: 0.2419 - val_mse: 0.2419
# Epoch 45/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2291 - mse: 0.2291 - val_loss: 0.2183 - val_mse: 0.2183
# Epoch 46/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2092 - mse: 0.2092 - val_loss: 0.2369 - val_mse: 0.2369
# Epoch 47/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2045 - mse: 0.2045 - val_loss: 0.2235 - val_mse: 0.2235
# Epoch 48/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2219 - mse: 0.2219 - val_loss: 0.2749 - val_mse: 0.2749
# Epoch 49/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2720 - mse: 0.2720 - val_loss: 0.2518 - val_mse: 0.2518
# Epoch 50/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3005 - mse: 0.3005 - val_loss: 0.2860 - val_mse: 0.2860
# Epoch 51/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2792 - mse: 0.2792 - val_loss: 0.2185 - val_mse: 0.2185
# Epoch 52/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2140 - mse: 0.2140 - val_loss: 0.2133 - val_mse: 0.2133
# Epoch 53/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2336 - mse: 0.2336 - val_loss: 0.2989 - val_mse: 0.2989
# Epoch 54/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2843 - mse: 0.2843 - val_loss: 0.2325 - val_mse: 0.2325
# Epoch 55/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2059 - mse: 0.2059 - val_loss: 0.2290 - val_mse: 0.2290
# Epoch 56/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1981 - mse: 0.1981 - val_loss: 0.2297 - val_mse: 0.2297
# Epoch 57/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2109 - mse: 0.2109 - val_loss: 0.2227 - val_mse: 0.2227
# Epoch 58/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1883 - mse: 0.1883 - val_loss: 0.2268 - val_mse: 0.2268
# Epoch 59/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2093 - mse: 0.2093 - val_loss: 0.2499 - val_mse: 0.2499
# Epoch 60/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2243 - mse: 0.2243 - val_loss: 0.3197 - val_mse: 0.3197
# Epoch 61/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2444 - mse: 0.2444 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 62/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2095 - mse: 0.2095 - val_loss: 0.2662 - val_mse: 0.2662
# Epoch 63/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2499 - mse: 0.2499 - val_loss: 0.2181 - val_mse: 0.2181
# Epoch 64/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2091 - mse: 0.2091 - val_loss: 0.2180 - val_mse: 0.2180
# Epoch 65/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1974 - mse: 0.1974 - val_loss: 0.2212 - val_mse: 0.2212
# Epoch 66/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1881 - mse: 0.1881 - val_loss: 0.2483 - val_mse: 0.2483
# Epoch 67/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2551 - mse: 0.2551 - val_loss: 0.2933 - val_mse: 0.2933
# Epoch 68/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2838 - mse: 0.2838 - val_loss: 0.2187 - val_mse: 0.2187
# Epoch 69/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2124 - mse: 0.2124 - val_loss: 0.2277 - val_mse: 0.2277
# Epoch 70/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1922 - mse: 0.1922 - val_loss: 0.2311 - val_mse: 0.2311
# Epoch 71/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2121 - mse: 0.2121 - val_loss: 0.2379 - val_mse: 0.2379
# Epoch 72/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2414 - mse: 0.2414 - val_loss: 0.2538 - val_mse: 0.2538
# Epoch 73/500
# 2/2 [==============================] - 0s 54ms/step - loss: 0.2400 - mse: 0.2400 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 74/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2050 - mse: 0.2050 - val_loss: 0.2371 - val_mse: 0.2371
# Epoch 75/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1822 - mse: 0.1822 - val_loss: 0.2396 - val_mse: 0.2396
# Epoch 76/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2363 - mse: 0.2363 - val_loss: 0.2156 - val_mse: 0.2156
# Epoch 77/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2144 - mse: 0.2144 - val_loss: 0.2505 - val_mse: 0.2505
# Epoch 78/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.2292 - val_mse: 0.2292
# Epoch 79/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1983 - mse: 0.1983 - val_loss: 0.2158 - val_mse: 0.2158
# Epoch 80/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1970 - mse: 0.1970 - val_loss: 0.2171 - val_mse: 0.2171
# Epoch 81/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1755 - mse: 0.1755 - val_loss: 0.2267 - val_mse: 0.2267
# Epoch 82/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2258 - mse: 0.2258 - val_loss: 0.2563 - val_mse: 0.2563
# Epoch 83/500
# 2/2 [==============================] - 0s 141ms/step - loss: 0.2724 - mse: 0.2724 - val_loss: 0.2382 - val_mse: 0.2382
# Epoch 84/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2212 - mse: 0.2212 - val_loss: 0.2108 - val_mse: 0.2108
# Epoch 85/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1880 - mse: 0.1880 - val_loss: 0.2406 - val_mse: 0.2406
# Epoch 86/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2476 - mse: 0.2476 - val_loss: 0.2618 - val_mse: 0.2618
# Epoch 87/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2511 - mse: 0.2511 - val_loss: 0.2099 - val_mse: 0.2099
# Epoch 88/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1858 - mse: 0.1858 - val_loss: 0.2290 - val_mse: 0.2290
# Epoch 89/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.2183 - val_mse: 0.2183
# Epoch 90/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1911 - mse: 0.1911 - val_loss: 0.2219 - val_mse: 0.2219
# Epoch 91/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1904 - mse: 0.1904 - val_loss: 0.2231 - val_mse: 0.2231
# Epoch 92/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1956 - mse: 0.1956 - val_loss: 0.2415 - val_mse: 0.2415
# Epoch 93/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2273 - mse: 0.2273 - val_loss: 0.2214 - val_mse: 0.2214
# Epoch 94/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1990 - mse: 0.1990 - val_loss: 0.2171 - val_mse: 0.2171
# Epoch 95/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.2786 - val_mse: 0.2786
# Epoch 96/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.2203 - val_mse: 0.2203
# Epoch 97/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2080 - mse: 0.2080 - val_loss: 0.2376 - val_mse: 0.2376
# Epoch 98/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2306 - mse: 0.2306 - val_loss: 0.2690 - val_mse: 0.2690
# Epoch 99/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2424 - mse: 0.2424 - val_loss: 0.2534 - val_mse: 0.2534
# Epoch 100/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2321 - mse: 0.2321 - val_loss: 0.2450 - val_mse: 0.2450
# Epoch 101/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2283 - mse: 0.2283 - val_loss: 0.2210 - val_mse: 0.2210
# Epoch 102/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1888 - mse: 0.1888 - val_loss: 0.2240 - val_mse: 0.2240
# Epoch 103/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1809 - mse: 0.1809 - val_loss: 0.2242 - val_mse: 0.2242
# Epoch 104/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1968 - mse: 0.1968 - val_loss: 0.2083 - val_mse: 0.2083
# Epoch 105/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1824 - mse: 0.1824 - val_loss: 0.2481 - val_mse: 0.2481
# Epoch 106/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2189 - mse: 0.2189 - val_loss: 0.2357 - val_mse: 0.2357
# Epoch 107/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1769 - mse: 0.1769 - val_loss: 0.2082 - val_mse: 0.2082
# Epoch 108/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1930 - mse: 0.1930 - val_loss: 0.2257 - val_mse: 0.2257
# Epoch 109/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2060 - mse: 0.2060 - val_loss: 0.2761 - val_mse: 0.2761
# Epoch 110/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2462 - mse: 0.2462 - val_loss: 0.2231 - val_mse: 0.2231
# Epoch 111/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1910 - mse: 0.1910 - val_loss: 0.2272 - val_mse: 0.2272
# Epoch 112/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1819 - mse: 0.1819 - val_loss: 0.2117 - val_mse: 0.2117
# Epoch 113/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1862 - mse: 0.1862 - val_loss: 0.2536 - val_mse: 0.2536
# Epoch 114/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2279 - mse: 0.2279 - val_loss: 0.2633 - val_mse: 0.2633
# Epoch 115/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2421 - mse: 0.2421 - val_loss: 0.2258 - val_mse: 0.2258
# Epoch 116/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1898 - mse: 0.1898 - val_loss: 0.2277 - val_mse: 0.2277
# Epoch 117/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1833 - mse: 0.1833 - val_loss: 0.2140 - val_mse: 0.2140
# Epoch 118/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1874 - mse: 0.1874 - val_loss: 0.2409 - val_mse: 0.2409
# Epoch 119/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2011 - mse: 0.2011 - val_loss: 0.2111 - val_mse: 0.2111
# Epoch 120/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1744 - mse: 0.1744 - val_loss: 0.2680 - val_mse: 0.2680
# Epoch 121/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2110 - mse: 0.2110 - val_loss: 0.2225 - val_mse: 0.2225
# Epoch 122/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2040 - mse: 0.2040 - val_loss: 0.2467 - val_mse: 0.2467
# Epoch 123/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1889 - mse: 0.1889 - val_loss: 0.2143 - val_mse: 0.2143
# Epoch 124/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1830 - mse: 0.1830 - val_loss: 0.2175 - val_mse: 0.2175
# Epoch 125/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1868 - mse: 0.1868 - val_loss: 0.2428 - val_mse: 0.2428
# Epoch 126/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2236 - mse: 0.2236 - val_loss: 0.2392 - val_mse: 0.2392
# Epoch 127/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2088 - mse: 0.2088 - val_loss: 0.2334 - val_mse: 0.2334
# Epoch 128/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1841 - mse: 0.1841 - val_loss: 0.2071 - val_mse: 0.2071
# Epoch 129/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1762 - mse: 0.1762 - val_loss: 0.2113 - val_mse: 0.2113
# Epoch 130/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1740 - mse: 0.1740 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 131/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.2143 - val_mse: 0.2143
# Epoch 132/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1833 - mse: 0.1833 - val_loss: 0.2315 - val_mse: 0.2315
# Epoch 133/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1889 - mse: 0.1889 - val_loss: 0.2056 - val_mse: 0.2056
# Epoch 134/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1874 - mse: 0.1874 - val_loss: 0.2114 - val_mse: 0.2114
# Epoch 135/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1870 - mse: 0.1870 - val_loss: 0.2053 - val_mse: 0.2053
# Epoch 136/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1879 - mse: 0.1879 - val_loss: 0.3267 - val_mse: 0.3267
# Epoch 137/500
# 2/2 [==============================] - 0s 137ms/step - loss: 0.2810 - mse: 0.2810 - val_loss: 0.2070 - val_mse: 0.2070
# Epoch 138/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1764 - mse: 0.1764 - val_loss: 0.2141 - val_mse: 0.2141
# Epoch 139/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1805 - mse: 0.1805 - val_loss: 0.2108 - val_mse: 0.2108
# Epoch 140/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.2215 - val_mse: 0.2215
# Epoch 141/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1735 - mse: 0.1735 - val_loss: 0.2140 - val_mse: 0.2140
# Epoch 142/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1851 - mse: 0.1851 - val_loss: 0.2185 - val_mse: 0.2185
# Epoch 143/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1763 - mse: 0.1763 - val_loss: 0.2507 - val_mse: 0.2507
# Epoch 144/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2035 - mse: 0.2035 - val_loss: 0.2471 - val_mse: 0.2471
# Epoch 145/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2246 - mse: 0.2246 - val_loss: 0.2697 - val_mse: 0.2697
# Epoch 146/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2429 - mse: 0.2429 - val_loss: 0.2106 - val_mse: 0.2106
# Epoch 147/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1784 - mse: 0.1784 - val_loss: 0.2157 - val_mse: 0.2157
# Epoch 148/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1682 - mse: 0.1682 - val_loss: 0.2142 - val_mse: 0.2142
# Epoch 149/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1814 - mse: 0.1814 - val_loss: 0.2250 - val_mse: 0.2250
# Epoch 150/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2107 - mse: 0.2107 - val_loss: 0.2147 - val_mse: 0.2147
# Epoch 151/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1885 - mse: 0.1885 - val_loss: 0.2173 - val_mse: 0.2173
# Epoch 152/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.2207 - val_mse: 0.2207
# Epoch 153/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1929 - mse: 0.1929 - val_loss: 0.2217 - val_mse: 0.2217
# Epoch 154/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1937 - mse: 0.1937 - val_loss: 0.2086 - val_mse: 0.2086
# Epoch 155/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1982 - mse: 0.1982 - val_loss: 0.2145 - val_mse: 0.2145
# Epoch 156/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1815 - mse: 0.1815 - val_loss: 0.2242 - val_mse: 0.2242
# Epoch 157/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1873 - mse: 0.1873 - val_loss: 0.2079 - val_mse: 0.2079
# Epoch 158/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1948 - mse: 0.1948 - val_loss: 0.2142 - val_mse: 0.2142
# Epoch 159/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1847 - mse: 0.1847 - val_loss: 0.2391 - val_mse: 0.2391
# Epoch 160/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1934 - mse: 0.1934 - val_loss: 0.2765 - val_mse: 0.2765
# Epoch 161/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2711 - mse: 0.2711 - val_loss: 0.2324 - val_mse: 0.2324
# Epoch 162/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1850 - mse: 0.1850 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 163/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1757 - mse: 0.1757 - val_loss: 0.2079 - val_mse: 0.2079
# Epoch 164/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1775 - mse: 0.1775 - val_loss: 0.2196 - val_mse: 0.2196
# Epoch 165/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1932 - mse: 0.1932 - val_loss: 0.2231 - val_mse: 0.2231
# Epoch 166/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2020 - mse: 0.2020 - val_loss: 0.2441 - val_mse: 0.2441
# Epoch 167/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1630 - mse: 0.1630 - val_loss: 0.2127 - val_mse: 0.2127
# Epoch 168/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1989 - mse: 0.1989 - val_loss: 0.2375 - val_mse: 0.2375
# Epoch 169/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2088 - mse: 0.2088 - val_loss: 0.2255 - val_mse: 0.2255
# Epoch 170/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1962 - mse: 0.1962 - val_loss: 0.2222 - val_mse: 0.2222
# Epoch 171/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.2268 - val_mse: 0.2268
# Epoch 172/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1669 - mse: 0.1669 - val_loss: 0.2061 - val_mse: 0.2061
# Epoch 173/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1788 - mse: 0.1788 - val_loss: 0.2092 - val_mse: 0.2092
# Epoch 174/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1859 - mse: 0.1859 - val_loss: 0.2278 - val_mse: 0.2278
# Epoch 175/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2019 - mse: 0.2019 - val_loss: 0.2165 - val_mse: 0.2165
# Epoch 176/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1789 - mse: 0.1789 - val_loss: 0.2138 - val_mse: 0.2138
# Epoch 177/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.2207 - val_mse: 0.2207
# Epoch 178/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1860 - mse: 0.1860 - val_loss: 0.2394 - val_mse: 0.2394
# Epoch 179/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1988 - mse: 0.1988 - val_loss: 0.2155 - val_mse: 0.2155
# Epoch 180/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1890 - mse: 0.1890 - val_loss: 0.2077 - val_mse: 0.2077
# Epoch 181/500
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.2229 - val_mse: 0.2229
# Epoch 182/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1909 - mse: 0.1909 - val_loss: 0.2217 - val_mse: 0.2217
# Epoch 183/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1733 - mse: 0.1733 - val_loss: 0.2411 - val_mse: 0.2411
# Epoch 184/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.2200 - val_mse: 0.2200
# Epoch 185/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1950 - mse: 0.1950 - val_loss: 0.2085 - val_mse: 0.2085
# Epoch 186/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1817 - mse: 0.1817 - val_loss: 0.2100 - val_mse: 0.2100
# Epoch 187/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1768 - mse: 0.1768 - val_loss: 0.2156 - val_mse: 0.2156
# Epoch 188/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1718 - mse: 0.1718 - val_loss: 0.2368 - val_mse: 0.2368
# Epoch 189/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2200 - mse: 0.2200 - val_loss: 0.2560 - val_mse: 0.2560
# Epoch 190/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2157 - mse: 0.2157 - val_loss: 0.2090 - val_mse: 0.2090
# Epoch 191/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 192/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1705 - mse: 0.1705 - val_loss: 0.2199 - val_mse: 0.2199
# Epoch 193/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1748 - mse: 0.1748 - val_loss: 0.2108 - val_mse: 0.2108
# Epoch 194/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1880 - mse: 0.1880 - val_loss: 0.2417 - val_mse: 0.2417
# Epoch 195/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2203 - mse: 0.2203 - val_loss: 0.2550 - val_mse: 0.2550
# Epoch 196/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1973 - mse: 0.1973 - val_loss: 0.2090 - val_mse: 0.2090
# Epoch 197/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1722 - mse: 0.1722 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 198/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1934 - mse: 0.1934 - val_loss: 0.2539 - val_mse: 0.2539
# Epoch 199/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2372 - mse: 0.2372 - val_loss: 0.2148 - val_mse: 0.2148
# Epoch 200/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1856 - mse: 0.1856 - val_loss: 0.2110 - val_mse: 0.2110
# Epoch 201/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1841 - mse: 0.1841 - val_loss: 0.2058 - val_mse: 0.2058
# Epoch 202/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1692 - mse: 0.1692 - val_loss: 0.2137 - val_mse: 0.2137
# Epoch 203/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1712 - mse: 0.1712 - val_loss: 0.2055 - val_mse: 0.2055
# Epoch 204/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.2467 - val_mse: 0.2467
# Epoch 205/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2017 - mse: 0.2017 - val_loss: 0.2036 - val_mse: 0.2036
# Epoch 206/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1719 - mse: 0.1719 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 207/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1933 - mse: 0.1933 - val_loss: 0.2234 - val_mse: 0.2234
# Epoch 208/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1871 - mse: 0.1871 - val_loss: 0.2070 - val_mse: 0.2070
# Epoch 209/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1786 - mse: 0.1786 - val_loss: 0.2238 - val_mse: 0.2238
# Epoch 210/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1846 - mse: 0.1846 - val_loss: 0.2042 - val_mse: 0.2042
# Epoch 211/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1741 - mse: 0.1741 - val_loss: 0.2020 - val_mse: 0.2020
# Epoch 212/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1705 - mse: 0.1705 - val_loss: 0.2419 - val_mse: 0.2419
# Epoch 213/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1959 - mse: 0.1959 - val_loss: 0.2153 - val_mse: 0.2153
# Epoch 214/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1749 - mse: 0.1749 - val_loss: 0.2035 - val_mse: 0.2035
# Epoch 215/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1788 - mse: 0.1788 - val_loss: 0.2359 - val_mse: 0.2359
# Epoch 216/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1749 - mse: 0.1749 - val_loss: 0.2056 - val_mse: 0.2056
# Epoch 217/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1729 - mse: 0.1729 - val_loss: 0.2073 - val_mse: 0.2073
# Epoch 218/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1841 - mse: 0.1841 - val_loss: 0.2389 - val_mse: 0.2389
# Epoch 219/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2161 - mse: 0.2161 - val_loss: 0.2220 - val_mse: 0.2220
# Epoch 220/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1941 - mse: 0.1941 - val_loss: 0.2321 - val_mse: 0.2321
# Epoch 221/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2001 - mse: 0.2001 - val_loss: 0.2334 - val_mse: 0.2334
# Epoch 222/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1905 - mse: 0.1905 - val_loss: 0.2091 - val_mse: 0.2091
# Epoch 223/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1730 - mse: 0.1730 - val_loss: 0.2019 - val_mse: 0.2019
# Epoch 224/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1848 - mse: 0.1848 - val_loss: 0.2041 - val_mse: 0.2041
# Epoch 225/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1708 - mse: 0.1708 - val_loss: 0.2303 - val_mse: 0.2303
# Epoch 226/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2149 - mse: 0.2149 - val_loss: 0.2461 - val_mse: 0.2461
# Epoch 227/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1818 - mse: 0.1818 - val_loss: 0.1996 - val_mse: 0.1996
# Epoch 228/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1689 - mse: 0.1689 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 229/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1758 - mse: 0.1758 - val_loss: 0.2007 - val_mse: 0.2007
# Epoch 230/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1753 - mse: 0.1753 - val_loss: 0.2067 - val_mse: 0.2067
# Epoch 231/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1764 - mse: 0.1764 - val_loss: 0.2604 - val_mse: 0.2604
# Epoch 232/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2108 - mse: 0.2108 - val_loss: 0.2068 - val_mse: 0.2068
# Epoch 233/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1729 - mse: 0.1729 - val_loss: 0.2201 - val_mse: 0.2201
# Epoch 234/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1736 - mse: 0.1736 - val_loss: 0.2137 - val_mse: 0.2137
# Epoch 235/500
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1810 - mse: 0.1810 - val_loss: 0.2310 - val_mse: 0.2310
# Epoch 236/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1777 - mse: 0.1777 - val_loss: 0.2070 - val_mse: 0.2070
# Epoch 237/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1674 - mse: 0.1674 - val_loss: 0.2043 - val_mse: 0.2043
# Epoch 238/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1634 - mse: 0.1634 - val_loss: 0.2019 - val_mse: 0.2019
# Epoch 239/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1832 - mse: 0.1832 - val_loss: 0.2221 - val_mse: 0.2221
# Epoch 240/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1737 - mse: 0.1737 - val_loss: 0.2077 - val_mse: 0.2077
# Epoch 241/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1661 - mse: 0.1661 - val_loss: 0.2240 - val_mse: 0.2240
# Epoch 242/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1986 - mse: 0.1986 - val_loss: 0.2181 - val_mse: 0.2181
# Epoch 243/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1898 - mse: 0.1898 - val_loss: 0.2115 - val_mse: 0.2115
# Epoch 244/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1717 - mse: 0.1717 - val_loss: 0.2064 - val_mse: 0.2064
# Epoch 245/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1751 - mse: 0.1751 - val_loss: 0.2051 - val_mse: 0.2051
# Epoch 246/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1704 - mse: 0.1704 - val_loss: 0.2066 - val_mse: 0.2066
# Epoch 247/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1677 - mse: 0.1677 - val_loss: 0.2607 - val_mse: 0.2607
# Epoch 248/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.2195 - val_mse: 0.2195
# Epoch 249/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1924 - mse: 0.1924 - val_loss: 0.2158 - val_mse: 0.2158
# Epoch 250/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1772 - mse: 0.1772 - val_loss: 0.1961 - val_mse: 0.1961
# Epoch 251/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1562 - mse: 0.1562 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 252/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1723 - mse: 0.1723 - val_loss: 0.1975 - val_mse: 0.1975
# Epoch 253/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1719 - mse: 0.1719 - val_loss: 0.2382 - val_mse: 0.2382
# Epoch 254/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1788 - mse: 0.1788 - val_loss: 0.2000 - val_mse: 0.2000
# Epoch 255/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1669 - mse: 0.1669 - val_loss: 0.2080 - val_mse: 0.2080
# Epoch 256/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1921 - mse: 0.1921 - val_loss: 0.2133 - val_mse: 0.2133
# Epoch 257/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1851 - mse: 0.1851 - val_loss: 0.2227 - val_mse: 0.2227
# Epoch 258/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1997 - mse: 0.1997 - val_loss: 0.2052 - val_mse: 0.2052
# Epoch 259/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.2041 - val_mse: 0.2041
# Epoch 260/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1637 - mse: 0.1637 - val_loss: 0.2039 - val_mse: 0.2039
# Epoch 261/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1696 - mse: 0.1696 - val_loss: 0.1987 - val_mse: 0.1987
# Epoch 262/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1663 - mse: 0.1663 - val_loss: 0.2256 - val_mse: 0.2256
# Epoch 263/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2171 - mse: 0.2171 - val_loss: 0.2231 - val_mse: 0.2231
# Epoch 264/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1906 - mse: 0.1906 - val_loss: 0.2050 - val_mse: 0.2050
# Epoch 265/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1642 - mse: 0.1642 - val_loss: 0.2138 - val_mse: 0.2138
# Epoch 266/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1853 - mse: 0.1853 - val_loss: 0.2441 - val_mse: 0.2441
# Epoch 267/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1952 - mse: 0.1952 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 268/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1650 - mse: 0.1650 - val_loss: 0.2071 - val_mse: 0.2071
# Epoch 269/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1867 - mse: 0.1867 - val_loss: 0.2009 - val_mse: 0.2009
# Epoch 270/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1634 - mse: 0.1634 - val_loss: 0.1940 - val_mse: 0.1940
# Epoch 271/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1647 - mse: 0.1647 - val_loss: 0.2097 - val_mse: 0.2097
# Epoch 272/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1686 - mse: 0.1686 - val_loss: 0.2423 - val_mse: 0.2423
# Epoch 273/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.2145 - mse: 0.2145 - val_loss: 0.2400 - val_mse: 0.2400
# Epoch 274/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2097 - mse: 0.2097 - val_loss: 0.2070 - val_mse: 0.2070
# Epoch 275/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1769 - mse: 0.1769 - val_loss: 0.2024 - val_mse: 0.2024
# Epoch 276/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1752 - mse: 0.1752 - val_loss: 0.2004 - val_mse: 0.2004
# Epoch 277/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1683 - mse: 0.1683 - val_loss: 0.2119 - val_mse: 0.2119
# Epoch 278/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1764 - mse: 0.1764 - val_loss: 0.2152 - val_mse: 0.2152
# Epoch 279/500
# 2/2 [==============================] - 0s 139ms/step - loss: 0.1676 - mse: 0.1676 - val_loss: 0.2098 - val_mse: 0.2098
# Epoch 280/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1756 - mse: 0.1756 - val_loss: 0.1968 - val_mse: 0.1968
# Epoch 281/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1693 - mse: 0.1693 - val_loss: 0.2301 - val_mse: 0.2301
# Epoch 282/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1860 - mse: 0.1860 - val_loss: 0.2158 - val_mse: 0.2158
# Epoch 283/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1991 - mse: 0.1991 - val_loss: 0.2253 - val_mse: 0.2253
# Epoch 284/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1756 - mse: 0.1756 - val_loss: 0.1992 - val_mse: 0.1992
# Epoch 285/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1666 - mse: 0.1666 - val_loss: 0.2007 - val_mse: 0.2007
# Epoch 286/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1685 - mse: 0.1685 - val_loss: 0.2152 - val_mse: 0.2152
# Epoch 287/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1728 - mse: 0.1728 - val_loss: 0.2004 - val_mse: 0.2004
# Epoch 288/500
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1722 - mse: 0.1722 - val_loss: 0.2141 - val_mse: 0.2141
# Epoch 289/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1645 - mse: 0.1645 - val_loss: 0.2172 - val_mse: 0.2172
# Epoch 290/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1869 - mse: 0.1869 - val_loss: 0.2053 - val_mse: 0.2053
# Epoch 291/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1653 - mse: 0.1653 - val_loss: 0.2481 - val_mse: 0.2481
# Epoch 292/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1939 - mse: 0.1939 - val_loss: 0.2196 - val_mse: 0.2196
# Epoch 293/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2033 - mse: 0.2033 - val_loss: 0.2167 - val_mse: 0.2167
# Epoch 294/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1702 - mse: 0.1702 - val_loss: 0.1964 - val_mse: 0.1964
# Epoch 295/500
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1655 - mse: 0.1655 - val_loss: 0.1995 - val_mse: 0.1995
# Epoch 296/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1846 - mse: 0.1846 - val_loss: 0.2024 - val_mse: 0.2024
# Epoch 297/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1806 - mse: 0.1806 - val_loss: 0.2011 - val_mse: 0.2011
# Epoch 298/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1611 - mse: 0.1611 - val_loss: 0.2044 - val_mse: 0.2044
# Epoch 299/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1721 - mse: 0.1721 - val_loss: 0.2113 - val_mse: 0.2113
# Epoch 300/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1613 - mse: 0.1613 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 301/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1659 - mse: 0.1659 - val_loss: 0.2376 - val_mse: 0.2376
# Epoch 302/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1952 - mse: 0.1952 - val_loss: 0.1993 - val_mse: 0.1993
# Epoch 303/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1729 - mse: 0.1729 - val_loss: 0.1998 - val_mse: 0.1998
# Epoch 304/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1842 - mse: 0.1842 - val_loss: 0.2527 - val_mse: 0.2527
# Epoch 305/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1972 - mse: 0.1972 - val_loss: 0.2016 - val_mse: 0.2016
# Epoch 306/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1642 - mse: 0.1642 - val_loss: 0.2244 - val_mse: 0.2244
# Epoch 307/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1708 - mse: 0.1708 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 308/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1564 - mse: 0.1564 - val_loss: 0.1937 - val_mse: 0.1937
# Epoch 309/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1617 - mse: 0.1617 - val_loss: 0.2223 - val_mse: 0.2223
# Epoch 310/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1883 - mse: 0.1883 - val_loss: 0.2267 - val_mse: 0.2267
# Epoch 311/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2078 - mse: 0.2078 - val_loss: 0.1881 - val_mse: 0.1881
# Epoch 312/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1955 - val_mse: 0.1955
# Epoch 313/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1560 - mse: 0.1560 - val_loss: 0.2150 - val_mse: 0.2150
# Epoch 314/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1765 - mse: 0.1765 - val_loss: 0.2135 - val_mse: 0.2135
# Epoch 315/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1659 - mse: 0.1659 - val_loss: 0.2212 - val_mse: 0.2212
# Epoch 316/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1992 - mse: 0.1992 - val_loss: 0.2274 - val_mse: 0.2274
# Epoch 317/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1907 - mse: 0.1907 - val_loss: 0.1989 - val_mse: 0.1989
# Epoch 318/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1599 - mse: 0.1599 - val_loss: 0.2214 - val_mse: 0.2214
# Epoch 319/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1804 - mse: 0.1804 - val_loss: 0.2123 - val_mse: 0.2123
# Epoch 320/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1860 - mse: 0.1860 - val_loss: 0.2057 - val_mse: 0.2057
# Epoch 321/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 322/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1662 - mse: 0.1662 - val_loss: 0.2008 - val_mse: 0.2008
# Epoch 323/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1773 - mse: 0.1773 - val_loss: 0.2021 - val_mse: 0.2021
# Epoch 324/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1644 - mse: 0.1644 - val_loss: 0.2054 - val_mse: 0.2054
# Epoch 325/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1732 - mse: 0.1732 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 326/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1659 - mse: 0.1659 - val_loss: 0.2085 - val_mse: 0.2085
# Epoch 327/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1848 - mse: 0.1848 - val_loss: 0.2479 - val_mse: 0.2479
# Epoch 328/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.2148 - mse: 0.2148 - val_loss: 0.2046 - val_mse: 0.2046
# Epoch 329/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1604 - mse: 0.1604 - val_loss: 0.1996 - val_mse: 0.1996
# Epoch 330/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1791 - mse: 0.1791 - val_loss: 0.2080 - val_mse: 0.2080
# Epoch 331/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1768 - mse: 0.1768 - val_loss: 0.2069 - val_mse: 0.2069
# Epoch 332/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1787 - mse: 0.1787 - val_loss: 0.2132 - val_mse: 0.2132
# Epoch 333/500
# 2/2 [==============================] - 0s 137ms/step - loss: 0.1736 - mse: 0.1736 - val_loss: 0.2157 - val_mse: 0.2157
# Epoch 334/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1769 - mse: 0.1769 - val_loss: 0.2162 - val_mse: 0.2162
# Epoch 335/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1834 - mse: 0.1834 - val_loss: 0.1913 - val_mse: 0.1913
# Epoch 336/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1673 - mse: 0.1673 - val_loss: 0.1934 - val_mse: 0.1934
# Epoch 337/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.1962 - val_mse: 0.1962
# Epoch 338/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1695 - mse: 0.1695 - val_loss: 0.2275 - val_mse: 0.2275
# Epoch 339/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1738 - mse: 0.1738 - val_loss: 0.2012 - val_mse: 0.2012
# Epoch 340/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1703 - mse: 0.1703 - val_loss: 0.2017 - val_mse: 0.2017
# Epoch 341/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1672 - mse: 0.1672 - val_loss: 0.1945 - val_mse: 0.1945
# Epoch 342/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1645 - mse: 0.1645 - val_loss: 0.2294 - val_mse: 0.2294
# Epoch 343/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2135 - mse: 0.2135 - val_loss: 0.2151 - val_mse: 0.2151
# Epoch 344/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1714 - mse: 0.1714 - val_loss: 0.2116 - val_mse: 0.2116
# Epoch 345/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.1917 - val_mse: 0.1917
# Epoch 346/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1657 - mse: 0.1657 - val_loss: 0.2046 - val_mse: 0.2046
# Epoch 347/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1505 - mse: 0.1505 - val_loss: 0.1929 - val_mse: 0.1929
# Epoch 348/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1554 - mse: 0.1554 - val_loss: 0.2390 - val_mse: 0.2390
# Epoch 349/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1692 - mse: 0.1692 - val_loss: 0.1962 - val_mse: 0.1962
# Epoch 350/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1730 - mse: 0.1730 - val_loss: 0.2206 - val_mse: 0.2206
# Epoch 351/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2183 - mse: 0.2183 - val_loss: 0.2156 - val_mse: 0.2156
# Epoch 352/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2023 - mse: 0.2023 - val_loss: 0.2348 - val_mse: 0.2348
# Epoch 353/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1963 - mse: 0.1963 - val_loss: 0.1882 - val_mse: 0.1882
# Epoch 354/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1596 - mse: 0.1596 - val_loss: 0.1898 - val_mse: 0.1898
# Epoch 355/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1679 - mse: 0.1679 - val_loss: 0.2295 - val_mse: 0.2295
# Epoch 356/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1928 - mse: 0.1928 - val_loss: 0.2204 - val_mse: 0.2204
# Epoch 357/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1804 - mse: 0.1804 - val_loss: 0.2147 - val_mse: 0.2147
# Epoch 358/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1657 - mse: 0.1657 - val_loss: 0.2013 - val_mse: 0.2013
# Epoch 359/500
# ...
# Epoch 380/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1604 - mse: 0.1604 - val_loss: 0.2138 - val_mse: 0.2138
# Epoch 381/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1942 - mse: 0.1942 - val_loss: 0.2134 - val_mse: 0.2134
# Epoch 382/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1929 - mse: 0.1929 - val_loss: 0.2183 - val_mse: 0.2183
# Epoch 383/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1887 - mse: 0.1887 - val_loss: 0.1899 - val_mse: 0.1899
# Epoch 384/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1555 - mse: 0.1555 - val_loss: 0.1919 - val_mse: 0.1919
# Epoch 385/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1548 - mse: 0.1548 - val_loss: 0.2144 - val_mse: 0.2144
# Epoch 386/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1820 - mse: 0.1820 - val_loss: 0.1918 - val_mse: 0.1918
# Epoch 387/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1571 - mse: 0.1571 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 388/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1500 - mse: 0.1500 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 389/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1654 - mse: 0.1654 - val_loss: 0.2105 - val_mse: 0.2105
# Epoch 390/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1785 - mse: 0.1785 - val_loss: 0.1919 - val_mse: 0.1919
# Epoch 391/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1621 - mse: 0.1621 - val_loss: 0.2197 - val_mse: 0.2197
# Epoch 392/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1977 - mse: 0.1977 - val_loss: 0.1935 - val_mse: 0.1935
# Epoch 393/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1652 - mse: 0.1652 - val_loss: 0.1922 - val_mse: 0.1922
# Epoch 394/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1571 - mse: 0.1571 - val_loss: 0.2023 - val_mse: 0.2023
# Epoch 395/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1802 - mse: 0.1802 - val_loss: 0.1942 - val_mse: 0.1942
# Epoch 396/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1518 - mse: 0.1518 - val_loss: 0.1917 - val_mse: 0.1917
# Epoch 397/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1644 - mse: 0.1644 - val_loss: 0.2001 - val_mse: 0.2001
# Epoch 398/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1706 - mse: 0.1706 - val_loss: 0.2103 - val_mse: 0.2103
# Epoch 399/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1761 - mse: 0.1761 - val_loss: 0.2433 - val_mse: 0.2433
# Epoch 400/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1931 - mse: 0.1931 - val_loss: 0.2381 - val_mse: 0.2381
# Epoch 401/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1948 - mse: 0.1948 - val_loss: 0.2069 - val_mse: 0.2069
# Epoch 402/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1835 - mse: 0.1835 - val_loss: 0.1967 - val_mse: 0.1967
# Epoch 403/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1558 - mse: 0.1558 - val_loss: 0.1920 - val_mse: 0.1920
# Epoch 404/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1550 - mse: 0.1550 - val_loss: 0.2072 - val_mse: 0.2072
# Epoch 405/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1709 - mse: 0.1709 - val_loss: 0.2616 - val_mse: 0.2616
# Epoch 406/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2187 - mse: 0.2187 - val_loss: 0.1966 - val_mse: 0.1966
# Epoch 407/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1586 - mse: 0.1586 - val_loss: 0.1916 - val_mse: 0.1916
# Epoch 408/500
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1470 - mse: 0.1470 - val_loss: 0.1938 - val_mse: 0.1938
# Epoch 409/500
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1632 - mse: 0.1632 - val_loss: 0.1950 - val_mse: 0.1950
# Epoch 410/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1602 - mse: 0.1602 - val_loss: 0.2316 - val_mse: 0.2316
# Epoch 411/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1928 - mse: 0.1928 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 412/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1582 - mse: 0.1582 - val_loss: 0.2075 - val_mse: 0.2075
# Epoch 413/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1776 - mse: 0.1776 - val_loss: 0.2160 - val_mse: 0.2160
# Epoch 414/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1914 - mse: 0.1914 - val_loss: 0.1935 - val_mse: 0.1935
# Epoch 415/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1719 - mse: 0.1719 - val_loss: 0.2063 - val_mse: 0.2063
# Epoch 416/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1631 - mse: 0.1631 - val_loss: 0.2116 - val_mse: 0.2116
# Epoch 417/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1852 - mse: 0.1852 - val_loss: 0.2608 - val_mse: 0.2608
# Epoch 418/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2256 - mse: 0.2256 - val_loss: 0.2021 - val_mse: 0.2021
# Epoch 419/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1729 - mse: 0.1729 - val_loss: 0.1852 - val_mse: 0.1852
# Epoch 420/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1599 - mse: 0.1599 - val_loss: 0.2014 - val_mse: 0.2014
# Epoch 421/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1625 - mse: 0.1625 - val_loss: 0.1938 - val_mse: 0.1938
# Epoch 422/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1543 - mse: 0.1543 - val_loss: 0.1998 - val_mse: 0.1998
# Epoch 423/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1565 - mse: 0.1565 - val_loss: 0.2179 - val_mse: 0.2179
# Epoch 424/500
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1910 - mse: 0.1910 - val_loss: 0.2010 - val_mse: 0.2010
# Epoch 425/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1910 - val_mse: 0.1910
# Epoch 426/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1594 - mse: 0.1594 - val_loss: 0.1835 - val_mse: 0.1835
# Epoch 427/500
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1529 - mse: 0.1529 - val_loss: 0.2096 - val_mse: 0.2096
# Epoch 428/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1905 - mse: 0.1905 - val_loss: 0.2280 - val_mse: 0.2280
# Epoch 429/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1933 - mse: 0.1933 - val_loss: 0.1994 - val_mse: 0.1994
# Epoch 430/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1635 - mse: 0.1635 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 431/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2084 - mse: 0.2084 - val_loss: 0.1993 - val_mse: 0.1993
# Epoch 432/500
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1736 - mse: 0.1736 - val_loss: 0.2101 - val_mse: 0.2101
# Epoch 433/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1671 - mse: 0.1671 - val_loss: 0.1960 - val_mse: 0.1960
# Epoch 434/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1617 - mse: 0.1617 - val_loss: 0.2218 - val_mse: 0.2218
# Epoch 435/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1806 - mse: 0.1806 - val_loss: 0.1924 - val_mse: 0.1924
# Epoch 436/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1718 - mse: 0.1718 - val_loss: 0.2188 - val_mse: 0.2188
# Epoch 437/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1923 - mse: 0.1923 - val_loss: 0.1986 - val_mse: 0.1986
# Epoch 438/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1742 - mse: 0.1742 - val_loss: 0.2084 - val_mse: 0.2084
# Epoch 439/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1657 - mse: 0.1657 - val_loss: 0.1950 - val_mse: 0.1950
# Epoch 440/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1542 - mse: 0.1542 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 441/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1661 - mse: 0.1661 - val_loss: 0.2005 - val_mse: 0.2005
# Epoch 442/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1862 - mse: 0.1862 - val_loss: 0.2240 - val_mse: 0.2240
# Epoch 443/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1763 - mse: 0.1763 - val_loss: 0.1937 - val_mse: 0.1937
# Epoch 444/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1606 - mse: 0.1606 - val_loss: 0.1925 - val_mse: 0.1925
# Epoch 445/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1589 - mse: 0.1589 - val_loss: 0.1885 - val_mse: 0.1885
# Epoch 446/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1708 - mse: 0.1708 - val_loss: 0.2078 - val_mse: 0.2078
# Epoch 447/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1746 - mse: 0.1746 - val_loss: 0.2380 - val_mse: 0.2380
# Epoch 448/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1824 - mse: 0.1824 - val_loss: 0.2121 - val_mse: 0.2121
# Epoch 449/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1684 - mse: 0.1684 - val_loss: 0.1992 - val_mse: 0.1992
# Epoch 450/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1598 - mse: 0.1598 - val_loss: 0.2006 - val_mse: 0.2006
# Epoch 451/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1733 - mse: 0.1733 - val_loss: 0.2282 - val_mse: 0.2282
# Epoch 452/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1710 - mse: 0.1710 - val_loss: 0.1872 - val_mse: 0.1872
# Epoch 453/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1526 - mse: 0.1526 - val_loss: 0.1889 - val_mse: 0.1889
# Epoch 454/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1656 - mse: 0.1656 - val_loss: 0.2010 - val_mse: 0.2010
# Epoch 455/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1838 - mse: 0.1838 - val_loss: 0.2110 - val_mse: 0.2110
# Epoch 456/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1629 - mse: 0.1629 - val_loss: 0.1966 - val_mse: 0.1966
# Epoch 457/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1653 - mse: 0.1653 - val_loss: 0.2251 - val_mse: 0.2251
# Epoch 458/500
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1756 - mse: 0.1756 - val_loss: 0.2235 - val_mse: 0.2235
# Epoch 459/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1965 - mse: 0.1965 - val_loss: 0.2018 - val_mse: 0.2018
# Epoch 460/500
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1703 - mse: 0.1703 - val_loss: 0.1861 - val_mse: 0.1861
# Epoch 461/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1626 - mse: 0.1626 - val_loss: 0.1899 - val_mse: 0.1899
# Epoch 462/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1693 - mse: 0.1693 - val_loss: 0.2257 - val_mse: 0.2257
# Epoch 463/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1961 - mse: 0.1961 - val_loss: 0.1948 - val_mse: 0.1948
# Epoch 464/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1705 - mse: 0.1705 - val_loss: 0.1842 - val_mse: 0.1842
# Epoch 465/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1557 - mse: 0.1557 - val_loss: 0.1981 - val_mse: 0.1981
# Epoch 466/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1467 - mse: 0.1467 - val_loss: 0.2220 - val_mse: 0.2220
# Epoch 467/500
# 2/2 [==============================] - 0s 58ms/step - loss: 0.2040 - mse: 0.2040 - val_loss: 0.2136 - val_mse: 0.2136
# Epoch 468/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1731 - mse: 0.1731 - val_loss: 0.1853 - val_mse: 0.1853
# Epoch 469/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1586 - mse: 0.1586 - val_loss: 0.1902 - val_mse: 0.1902
# Epoch 470/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1491 - mse: 0.1491 - val_loss: 0.1921 - val_mse: 0.1921
# Epoch 471/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1648 - mse: 0.1648 - val_loss: 0.2159 - val_mse: 0.2159
# Epoch 472/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1715 - mse: 0.1715 - val_loss: 0.2290 - val_mse: 0.2290
# Epoch 473/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1864 - mse: 0.1864 - val_loss: 0.1906 - val_mse: 0.1906
# Epoch 474/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1450 - mse: 0.1450 - val_loss: 0.1879 - val_mse: 0.1879
# Epoch 475/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1568 - mse: 0.1568 - val_loss: 0.1968 - val_mse: 0.1968
# Epoch 476/500
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1934 - mse: 0.1934 - val_loss: 0.2140 - val_mse: 0.2140
# Epoch 477/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1993 - mse: 0.1993 - val_loss: 0.1960 - val_mse: 0.1960
# Epoch 478/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1516 - mse: 0.1516 - val_loss: 0.2061 - val_mse: 0.2061
# Epoch 479/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1617 - mse: 0.1617 - val_loss: 0.2166 - val_mse: 0.2166
# Epoch 480/500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1660 - mse: 0.1660 - val_loss: 0.2036 - val_mse: 0.2036
# Epoch 481/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1600 - mse: 0.1600 - val_loss: 0.2059 - val_mse: 0.2059
# Epoch 482/500
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1872 - val_mse: 0.1872
# Epoch 483/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1505 - mse: 0.1505 - val_loss: 0.2211 - val_mse: 0.2211
# Epoch 484/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1724 - mse: 0.1724 - val_loss: 0.2057 - val_mse: 0.2057
# Epoch 485/500
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1625 - mse: 0.1625 - val_loss: 0.1901 - val_mse: 0.1901
# Epoch 486/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1521 - mse: 0.1521 - val_loss: 0.1925 - val_mse: 0.1925
# Epoch 487/500
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1652 - mse: 0.1652 - val_loss: 0.2087 - val_mse: 0.2087
# Epoch 488/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1906 - mse: 0.1906 - val_loss: 0.2492 - val_mse: 0.2492
# Epoch 489/500
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.1949 - val_mse: 0.1949
# Epoch 490/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1601 - mse: 0.1601 - val_loss: 0.1862 - val_mse: 0.1862
# Epoch 491/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1575 - mse: 0.1575 - val_loss: 0.1986 - val_mse: 0.1986
# Epoch 492/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1616 - mse: 0.1616 - val_loss: 0.2033 - val_mse: 0.2033
# Epoch 493/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1619 - mse: 0.1619 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 494/500
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1566 - mse: 0.1566 - val_loss: 0.2076 - val_mse: 0.2076
# Epoch 495/500
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1842 - mse: 0.1842 - val_loss: 0.1934 - val_mse: 0.1934
# Epoch 496/500
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1692 - mse: 0.1692 - val_loss: 0.1967 - val_mse: 0.1967
# Epoch 497/500
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1813 - mse: 0.1813 - val_loss: 0.2291 - val_mse: 0.2291
# Epoch 498/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1689 - mse: 0.1689 - val_loss: 0.2083 - val_mse: 0.2083
# Epoch 499/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1772 - mse: 0.1772 - val_loss: 0.1858 - val_mse: 0.1858
# Epoch 500/500
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1517 - mse: 0.1517 - val_loss: 0.1889 - val_mse: 0.1889

# %% [markdown]
# Plot loss

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1.0])
  plt.xlabel('Epoch')
  plt.ylabel('Error ')
  plt.legend()
  plt.grid(True)

plot_loss(history)

# %% [markdown]
# Evaluate neural network

# %%
results = model0.evaluate(XX_test_n, yy_test_n)

print('loss test data: ', results[0])
print('mse test data: ', results[1])

results = model0.evaluate(XX_train_n, yy_train_n)

print('loss train data: ', results[0])
print('mse train data: ', results[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1889 - mse: 0.1889
# loss test data:  0.18894270062446594
# mse test data:  0.18894270062446594
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1489 - mse: 0.1489
# loss train data:  0.14886942505836487
# mse train data:  0.14886942505836487

# %% [markdown]
# Plot results

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(XX_train_n,yy_train_n, 'o', color='blue', label='Training points')
plt.plot(XX_test_n,yy_test_n, 'o', color='green', label='Testing points')

points = np.linspace(min(XX_test_n), max(XX_test_n),num=100)
plt.plot(points, (funct(points*std+mean)-mean1)/std1,  color='red', label='Function')

plt.plot(points, model0.predict(points),  color='orange', label='Neural net')


plt.legend()


plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras import optimizers

import numpy as np
import matplotlib.pyplot as plt

# %%
def funct(x):
  return x*x*np.sin(x)+np.log(2*x)

size = 150
low=0
high=12
error=5

XX_train = np.random.uniform(low=low, high=high, size=size)
XX_test = np.random.uniform(low=low, high=high, size=size)
yy_train = funct(XX_train) + np.random.normal(0., error, size)
yy_test = funct(XX_test) + np.random.normal(0., error, size)

print(XX_train.shape, yy_train.shape)

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(XX_train,yy_train, 'o', color='blue', label='Training points')
plt.plot(XX_test,yy_test, 'o', color='green', label='Testing points')

points = np.linspace(low, high,num=100)
plt.plot(points, funct(points),  color='red', label='Function')
plt.legend()


plt.show

# %%
# - odjąć średnią
# - podzielić przez odchylenie standardowe

# 
mean = XX_train.mean(axis=0)
XX_train_n = XX_train-mean
std = XX_train_n.std(axis=0)
XX_train_n /= std

# to samo dla x_test
XX_test_n = XX_test - mean
XX_test_n /= std

mean1 = yy_train.mean(axis=0)
yy_train_n = yy_train-mean1
std1 = yy_train_n.std(axis=0)
yy_train_n /= std1

# to samo dla y_test
yy_test_n = yy_test - mean1
yy_test_n /= std1

# A teraz to samo dla yy_train i yy_test
# dopisać to samo dla y

# %%
# Zbudować sieć neuronową, działa: dwie warstwy ukryte, aktywacja relu
from keras import models
from keras import layers
from keras import regularizers

model0 = Sequential(name='network')
#.....
model0.add(layers.Dense(1024,kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(1,)))
model0.add(layers.Dense(1024,kernel_regularizer=regularizers.l2(0.001), activation='relu'))
model0.add(layers.Dense(1, activation='linear'))

model0.summary()

# %%
# compile and train NN
# Uwaga: dla regresji używamy: loss = 'mean_squared_error'   oraz metrics = ['mse']
opt=optimizers.RMSprop(lr=0.002)
model0.compile(optimizer=opt,
                       loss='mean_squared_error',
                       metrics=['mse'])
history = model0.fit(XX_train_n, yy_train_n,
                                     epochs=600,
                                     batch_size=128,
                                     validation_data=(XX_test_n, yy_test_n),
                                     verbose = 1)

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1.5])
  plt.xlabel('Epoch')
  plt.ylabel('Error ')
  plt.legend()
  plt.grid(True)

plot_loss(history)

# %%
results = model0.evaluate(XX_test_n, yy_test_n)

print('loss test data: ', results[0])
print('mse test data: ', results[1])

results = model0.evaluate(XX_train_n, yy_train_n)

print('loss train data: ', results[0])
print('mse train data: ', results[1])

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(XX_train_n,yy_train_n, 'o', color='blue', label='Training points')
plt.plot(XX_test_n,yy_test_n, 'o', color='green', label='Testing points')

points = np.linspace(min(XX_test_n), max(XX_test_n),num=100)
plt.plot(points, (funct(points*std+mean)-mean1)/std1,  color='red', label='Function')

plt.plot(points, model0.predict(points),  color='orange', label='Neural net')

plt.legend()

plt.show

# %% [markdown]
# **The Boston Housing Price dataset**
#
# We will be attempting to predict the median price of homes in a given Boston suburb in the mid-1970s, given a few data points about the suburb at the time, such as the crime rate, the local property tax rate, etc.
#
# The dataset has very few data points, only 506 in total, split between 404 training samples and 102 test samples, and each "feature" in the input data (e.g. the crime rate is a feature) has a different scale. For instance some values are proportions, which take a values between 0 and 1, others take values between 1 and 12, others between 0 and 100...

# %%
from keras.datasets import boston_housing

(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %% [markdown]
# **Preparing the data**
#
# It would be problematic to feed into a neural network values that all take wildly different ranges. The network might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice to deal with such data is to do feature-wise normalization: for each feature in the input data (a column in the input data matrix), we will subtract the mean of the feature and divide by the standard deviation, so that the feature will be centered around 0 and will have a unit standard deviation. This is easily done in Numpy:

# %%
fig = plt.figure(figsize=(7,7))

plt.plot(XX_train,yy_train, 'o', color='blue', label='Training points')
plt.plot(XX_test,yy_test, 'o', color='green', label='Testing points')

points = np.linspace(low, high,num=100)
plt.plot(points, funct(points),  color='red', label='Function')
plt.legend()


plt.show

# %% [markdown]
# Define, compile and train neural network

# %%
model = Sequential()

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 0.5])
  plt.xlabel('Epoch')
  plt.ylabel('Error [MPG]')
  plt.legend()
  plt.grid(True)

plot_loss(history)

# %% [markdown]
# Evaluate neural network

# %%
results = model0.evaluate(X_test_n, y_test_n)

print('loss test data: ', results[0])
print('mse test data: ', results[1])

results = model0.evaluate(X_train_n, y_train_n)

print('loss train data: ', results[0])
print('mse train data: ', results[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1889 - mse: 0.1889
# loss test data:  0.18894270062446594
# mse test data:  0.18894270062446594
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1489 - mse: 0.1489
# loss train data:  0.14886942505836487
# mse train data:  0.14886942505836487
